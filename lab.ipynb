# %%
import pandas as pd

# %%
node = pd.read_csv("nodes.csv")

# %%
node.head(5)
# Out:
#                                                 link  \
# 0       /wiki/Gi%E1%BA%A3i_Nobel_V%E1%BA%ADt_l%C3%BD
# 1      /wiki/Gi%E1%BA%A3i_Nobel_H%C3%B3a_h%E1%BB%8Dc
# 2  /wiki/Gi%E1%BA%A3i_Nobel_Sinh_l%C3%BD_h%E1%BB%...
# 3      /wiki/Gi%E1%BA%A3i_Nobel_V%C4%83n_h%E1%BB%8Dc
# 4        /wiki/Gi%E1%BA%A3i_Nobel_H%C3%B2a_b%C3%ACnh
#
#                                 name   type
# 0                  Giải Nobel Vật lý  EVENT
# 1                 Giải Nobel hóa học  EVENT
# 2  Giải Nobel Sinh lý học hoặc Y học  EVENT
# 3                 Giải Nobel Văn học  EVENT
# 4                Giải Nobel Hòa bình  EVENT

# %%
node.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3939 entries, 0 to 3938
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   link    3939 non-null   object
#  1   name    3939 non-null   object
#  2   type    3939 non-null   object
# dtypes: object(3)
# memory usage: 92.4+ KB

# %%
nodes_dict = {
    item["link"]: {
        "name" : item["name"],
        "type" : item["type"]
    } for _, item in node.iterrows()
}

# %%
edges = pd.read_csv("edges.csv")

# %%
edges.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10122 entries, 0 to 10121
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   src     10122 non-null  object
#  1   des     10122 non-null  object
#  2   type    10122 non-null  object
# dtypes: object(3)
# memory usage: 237.4+ KB

# %%
s = set()

for _, edge in edges.iterrows():
    # print(edge["src"], edge["des"], edge["type"])
    try:
        s.add((nodes_dict[edge["src"]]["type"], edge["type"], nodes_dict[edge["des"]]["type"]))
    except Exception as e:
        print(e)
# Out:
# '/w/index.php?title=William_I._F._David&action=edit&redlink=1'
# '/w/index.php?title=Viktor_Meyer&action=edit&redlink=1'
# 'https://en.wikipedia.org/wiki/Doctoral_advisor'
# '/w/index.php?title=Open_University&action=edit&redlink=1'
# '/w/index.php?title=%C4%90%E1%BA%A1i_h%E1%BB%8Dc_Indiana_c%C6%A1_s%E1%BB%9F_Bloomington&action=edit&redlink=1'
# 'https://en.wikipedia.org/wiki/Doctoral_advisor'
# 'https://en.wikipedia.org/wiki/Doctoral_advisor'
# '/w/index.php?title=V%C6%B0%C6%A1ng_qu%E1%BB%91c_Ba_Lan_(1385%E2%80%931569)&action=edit&redlink=1'
# '/wiki/%C4%90%E1%BA%A1i_h%E1%BB%8Dc_Bologna'
# '/w/index.php?title=Susan_Francia&action=edit&redlink=1'
# 'https://en.wikipedia.org/wiki/Doctoral_advisor'
# '/wiki/C%E1%BB%AD_nh%C3%A2n'
# '/w/index.php?title=Shaw_Prize&action=edit&redlink=1'
# '/wiki/%C4%90%E1%BA%A1i_h%E1%BB%8Dc_Saitama'
# '/w/index.php?title=The_Ritz_London_Hotel&action=edit&redlink=1'
# '/w/index.php?title=Fettes_College&action=edit&redlink=1'
# ...

# %%
print(f"Len: {len(s)}")

with open("relationship.txt", "w", encoding="utf-8") as f:
    for item in s:
        f.write(f"({item[0]}, {item[1]}, {item[2]})\n")
# Out:
# Len: 54
